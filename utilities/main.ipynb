# %%
import os
import shutil

def clear_folder(folder_path):
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        try:
            if os.path.isfile(item_path) or os.path.islink(item_path):
                os.remove(item_path)
            elif os.path.isdir(item_path):
                shutil.rmtree(item_path)
        except Exception as e:
            print(f"Failed to delete {item_path}. Reason: {e}")

# usage
folder_to_clear = "../data/output_texts"
clear_folder(folder_to_clear)
print(f"Cleared folder: {folder_to_clear}")
# Out:
# Cleared folder: ../data/output_texts

# %%
# Batching the CSV content into text files

import pandas as pd
import os

COLUMN_NAME = 'Tweet'

def read_csv_with_fallback_encodings(file_path, encodings=["utf-8", "cp1252", "latin1"]):
    for enc in encodings:
        try:
            df = pd.read_csv(file_path, encoding=enc)
            print(f"✅ Loaded CSV using encoding: {enc}")
            return df
        except UnicodeDecodeError:
            print(f"⚠️ Failed with encoding: {enc}")
    raise UnicodeDecodeError("All tried encodings failed.")

def save_csv_to_txt(csv_file, output_folder, column_name=COLUMN_NAME):
    # Try to read the CSV with multiple encodings
    df = read_csv_with_fallback_encodings(csv_file)

    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through each record in the 'Content' column
    for idx, row in df.iterrows():
        content = str(row.get(column_name, ''))  # Use .get in case the column doesn't exist
        file_path = os.path.join(output_folder, f'record_{idx + 1}.txt')

        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(content)

    print(f"\n🎉 Saved {len(df)} records to '{output_folder}'")

# Example usage
csv_file = "../data/csv/tweets_3.csv"
output_folder = "../data/output_texts/"
save_csv_to_txt(csv_file, output_folder, COLUMN_NAME)
# Out:
# ✅ Loaded CSV using encoding: utf-8
#
# 🎉 Saved 1188 records to '../data/output_texts/'

# %%
# Uploading the text files to FastAPI (SQLAlchemy) database

import os
import requests

# Path to the folder containing text files
FOLDER_PATH = r"../data/output_texts"
API_URL = "http://127.0.0.1:5000/api/v1/data/upload"
PROJECT_ID = "12"  # Change this to the correct project ID

def upload_file(file_path):
    """Uploads a single file to the FastAPI database."""
    file_name = os.path.basename(file_path)
    files = {
        "file": (file_name, open(file_path, "rb"), "text/plain")  # Force correct content-type
    }
    url = f"{API_URL}/{PROJECT_ID}"

    response = requests.post(url, files=files)

    if response.status_code == 200:
        print(f"✅ Successfully uploaded: {file_name}")
    else:
        print(f"❌ Failed to upload {file_name}. Response: {response.text}")

def upload_all_files():
    """Uploads all .txt files from the specified folder."""
    if not os.path.exists(FOLDER_PATH):
        print(f"❌ Folder not found: {FOLDER_PATH}")
        return

    txt_files = [f for f in os.listdir(FOLDER_PATH) if f.endswith(".txt")]

    if not txt_files:
        print("❌ No .txt files found in the folder.")
        return

    print(f"📂 Found {len(txt_files)} files. Uploading...")

    for file in txt_files:
        file_path = os.path.join(FOLDER_PATH, file)
        upload_file(file_path)

    print("🎉 All files uploaded successfully!")

if __name__ == "__main__":
    upload_all_files()
# Out:
# 📂 Found 1188 files. Uploading...
# ✅ Successfully uploaded: record_1.txt
# ✅ Successfully uploaded: record_10.txt
# ✅ Successfully uploaded: record_100.txt
# ✅ Successfully uploaded: record_1000.txt
# ✅ Successfully uploaded: record_1001.txt
# ✅ Successfully uploaded: record_1002.txt
# ✅ Successfully uploaded: record_1003.txt
# ✅ Successfully uploaded: record_1004.txt
# ✅ Successfully uploaded: record_1005.txt
# ✅ Successfully uploaded: record_1006.txt
# ✅ Successfully uploaded: record_1007.txt
# ✅ Successfully uploaded: record_1008.txt
# ✅ Successfully uploaded: record_1009.txt
# ✅ Successfully uploaded: record_101.txt
# ✅ Successfully uploaded: record_1010.txt
# ✅ Successfully uploaded: record_1011.txt
# ✅ Successfully uploaded: record_1012.txt
# ✅ Successfully uploaded: record_1013.txt
# ✅ Successfully uploaded: record_1014.txt
# ✅ Successfully uploaded: record_1015.txt
# ✅ Successfully uploaded: record_1016.txt
# ✅ Successfully uploaded: record_1017.txt
# ✅ Successfully uploaded: record_1018.txt
# ✅ Successfully uploaded: record_1019.txt
# ✅ Successfully uploaded: record_102.txt
# ✅ Successfully uploaded: record_1020.txt
# ✅ Successfully uploaded: record_1021.txt
# ✅ Successfully uploaded: record_1022.txt
# ✅ Successfully uploaded: record_1023.txt
# ✅ Successfully uploaded: record_1024.txt
# ✅ Successfully uploaded: record_1025.txt
# ✅ Successfully uploaded: record_1026.txt
# ✅ Successfully uploaded: record_1027.txt
# ✅ Successfully uploaded: record_1028.txt
# ✅ Successfully uploaded: record_1029.txt
# ✅ Successfully uploaded: record_103.txt
# ✅ Successfully uploaded: record_1030.txt
# ✅ Successfully uploaded: record_1031.txt
# ✅ Successfully uploaded: record_1032.txt
# ✅ Successfully uploaded: record_1033.txt
# ✅ Successfully uploaded: record_1034.txt
# ✅ Successfully uploaded: record_1035.txt
# ✅ Successfully uploaded: record_1036.txt
# ✅ Successfully uploaded: record_1037.txt
# ✅ Successfully uploaded: record_1038.txt
# ✅ Successfully uploaded: record_1039.txt
# ✅ Successfully uploaded: record_104.txt
# ✅ Successfully uploaded: record_1040.txt
# ✅ Successfully uploaded: record_1041.txt
# ✅ Successfully uploaded: record_1042.txt
# ✅ Successfully uploaded: record_1043.txt
# ✅ Successfully uploaded: record_1044.txt
# ✅ Successfully uploaded: record_1045.txt
# ✅ Successfully uploaded: record_1046.txt
# ✅ Successfully uploaded: record_1047.txt
# ✅ Successfully uploaded: record_1048.txt
# ✅ Successfully uploaded: record_1049.txt
# ✅ Successfully uploaded: record_105.txt
# ✅ Successfully uploaded: record_1050.txt
# ✅ Successfully uploaded: record_1051.txt
# ✅ Successfully uploaded: record_1052.txt
# ✅ Successfully uploaded: record_1053.txt
# ✅ Successfully uploaded: record_1054.txt
# ✅ Successfully uploaded: record_1055.txt
# ✅ Successfully uploaded: record_1056.txt
# ✅ Successfully uploaded: record_1057.txt
# ✅ Successfully uploaded: record_1058.txt
# ✅ Successfully uploaded: record_1059.txt
# ✅ Successfully uploaded: record_106.txt
# ✅ Successfully uploaded: record_1060.txt
# ✅ Successfully uploaded: record_1061.txt
# ✅ Successfully uploaded: record_1062.txt
# ✅ Successfully uploaded: record_1063.txt
# ✅ Successfully uploaded: record_1064.txt
# ✅ Successfully uploaded: record_1065.txt
# ✅ Successfully uploaded: record_1066.txt
# ✅ Successfully uploaded: record_1067.txt
# ✅ Successfully uploaded: record_1068.txt
# ✅ Successfully uploaded: record_1069.txt
# ✅ Successfully uploaded: record_107.txt
# ✅ Successfully uploaded: record_1070.txt
# ✅ Successfully uploaded: record_1071.txt
# ✅ Successfully uploaded: record_1072.txt
# ✅ Successfully uploaded: record_1073.txt
# ✅ Successfully uploaded: record_1074.txt
# ✅ Successfully uploaded: record_1075.txt
# ✅ Successfully uploaded: record_1076.txt
# ✅ Successfully uploaded: record_1077.txt
# ✅ Successfully uploaded: record_1078.txt
# ✅ Successfully uploaded: record_1079.txt
# ✅ Successfully uploaded: record_108.txt
# ✅ Successfully uploaded: record_1080.txt
# ✅ Successfully uploaded: record_1081.txt
# ✅ Successfully uploaded: record_1082.txt
# ✅ Successfully uploaded: record_1083.txt
# ✅ Successfully uploaded: record_1084.txt
# ✅ Successfully uploaded: record_1085.txt
# ✅ Successfully uploaded: record_1086.txt
# ✅ Successfully uploaded: record_1087.txt
# ✅ Successfully uploaded: record_1088.txt
# ✅ Successfully uploaded: record_1089.txt
# ✅ Successfully uploaded: record_109.txt
# ✅ Successfully uploaded: record_1090.txt
# ✅ Successfully uploaded: record_1091.txt
# ✅ Successfully uploaded: record_1092.txt
# ✅ Successfully uploaded: record_1093.txt
# ✅ Successfully uploaded: record_1094.txt
# ✅ Successfully uploaded: record_1095.txt
# ✅ Successfully uploaded: record_1096.txt
# ✅ Successfully uploaded: record_1097.txt
# ✅ Successfully uploaded: record_1098.txt
# ✅ Successfully uploaded: record_1099.txt
# ✅ Successfully uploaded: record_11.txt
# ✅ Successfully uploaded: record_110.txt
# ✅ Successfully uploaded: record_1100.txt
# ✅ Successfully uploaded: record_1101.txt
# ✅ Successfully uploaded: record_1102.txt
# ✅ Successfully uploaded: record_1103.txt
# ✅ Successfully uploaded: record_1104.txt
# ✅ Successfully uploaded: record_1105.txt
# ✅ Successfully uploaded: record_1106.txt
# ✅ Successfully uploaded: record_1107.txt
# ✅ Successfully uploaded: record_1108.txt
# ✅ Successfully uploaded: record_1109.txt
# ✅ Successfully uploaded: record_111.txt
# ✅ Successfully uploaded: record_1110.txt
# ✅ Successfully uploaded: record_1111.txt
# ✅ Successfully uploaded: record_1112.txt
# ✅ Successfully uploaded: record_1113.txt
# ✅ Successfully uploaded: record_1114.txt
# ✅ Successfully uploaded: record_1115.txt
# ✅ Successfully uploaded: record_1116.txt
# ✅ Successfully uploaded: record_1117.txt
# ✅ Successfully uploaded: record_1118.txt
# ✅ Successfully uploaded: record_1119.txt
# ✅ Successfully uploaded: record_112.txt
# ✅ Successfully uploaded: record_1120.txt
# ✅ Successfully uploaded: record_1121.txt
# ✅ Successfully uploaded: record_1122.txt
# ✅ Successfully uploaded: record_1123.txt
# ✅ Successfully uploaded: record_1124.txt
# ✅ Successfully uploaded: record_1125.txt
# ✅ Successfully uploaded: record_1126.txt
# ✅ Successfully uploaded: record_1127.txt
# ✅ Successfully uploaded: record_1128.txt
# ✅ Successfully uploaded: record_1129.txt
# ✅ Successfully uploaded: record_113.txt
# ✅ Successfully uploaded: record_1130.txt
# ✅ Successfully uploaded: record_1131.txt
# ✅ Successfully uploaded: record_1132.txt
# ✅ Successfully uploaded: record_1133.txt
# ✅ Successfully uploaded: record_1134.txt
# ✅ Successfully uploaded: record_1135.txt
# ✅ Successfully uploaded: record_1136.txt
# ✅ Successfully uploaded: record_1137.txt
# ✅ Successfully uploaded: record_1138.txt
# ✅ Successfully uploaded: record_1139.txt
# ✅ Successfully uploaded: record_114.txt
# ✅ Successfully uploaded: record_1140.txt
# ✅ Successfully uploaded: record_1141.txt
# ✅ Successfully uploaded: record_1142.txt
# ✅ Successfully uploaded: record_1143.txt
# ✅ Successfully uploaded: record_1144.txt
# ✅ Successfully uploaded: record_1145.txt
# ✅ Successfully uploaded: record_1146.txt
# ✅ Successfully uploaded: record_1147.txt
# ✅ Successfully uploaded: record_1148.txt
# ✅ Successfully uploaded: record_1149.txt
# ✅ Successfully uploaded: record_115.txt
# ✅ Successfully uploaded: record_1150.txt
# ✅ Successfully uploaded: record_1151.txt
# ✅ Successfully uploaded: record_1152.txt
# ✅ Successfully uploaded: record_1153.txt
# ✅ Successfully uploaded: record_1154.txt
# ✅ Successfully uploaded: record_1155.txt
# ✅ Successfully uploaded: record_1156.txt
# ✅ Successfully uploaded: record_1157.txt
# ✅ Successfully uploaded: record_1158.txt
# ✅ Successfully uploaded: record_1159.txt
# ✅ Successfully uploaded: record_116.txt
# ✅ Successfully uploaded: record_1160.txt
# ✅ Successfully uploaded: record_1161.txt
# ✅ Successfully uploaded: record_1162.txt
# ✅ Successfully uploaded: record_1163.txt
# ✅ Successfully uploaded: record_1164.txt
# ✅ Successfully uploaded: record_1165.txt
# ✅ Successfully uploaded: record_1166.txt
# ✅ Successfully uploaded: record_1167.txt
# ✅ Successfully uploaded: record_1168.txt
# ✅ Successfully uploaded: record_1169.txt
# ✅ Successfully uploaded: record_117.txt
# ✅ Successfully uploaded: record_1170.txt
# ✅ Successfully uploaded: record_1171.txt
# ✅ Successfully uploaded: record_1172.txt
# ✅ Successfully uploaded: record_1173.txt
# ✅ Successfully uploaded: record_1174.txt
# ✅ Successfully uploaded: record_1175.txt
# ✅ Successfully uploaded: record_1176.txt
# ✅ Successfully uploaded: record_1177.txt
# ✅ Successfully uploaded: record_1178.txt
# ✅ Successfully uploaded: record_1179.txt
# ✅ Successfully uploaded: record_118.txt
# ✅ Successfully uploaded: record_1180.txt
# ✅ Successfully uploaded: record_1181.txt
# ✅ Successfully uploaded: record_1182.txt
# ✅ Successfully uploaded: record_1183.txt
# ✅ Successfully uploaded: record_1184.txt
# ✅ Successfully uploaded: record_1185.txt
# ✅ Successfully uploaded: record_1186.txt
# ✅ Successfully uploaded: record_1187.txt
# ✅ Successfully uploaded: record_1188.txt
# ✅ Successfully uploaded: record_119.txt
# ✅ Successfully uploaded: record_12.txt
# ✅ Successfully uploaded: record_120.txt
# ✅ Successfully uploaded: record_121.txt
# ✅ Successfully uploaded: record_122.txt
# ✅ Successfully uploaded: record_123.txt
# ✅ Successfully uploaded: record_124.txt
# ✅ Successfully uploaded: record_125.txt
# ✅ Successfully uploaded: record_126.txt
# ✅ Successfully uploaded: record_127.txt
# ✅ Successfully uploaded: record_128.txt
# ✅ Successfully uploaded: record_129.txt
# ✅ Successfully uploaded: record_13.txt
# ✅ Successfully uploaded: record_130.txt
# ✅ Successfully uploaded: record_131.txt
# ✅ Successfully uploaded: record_132.txt
# ✅ Successfully uploaded: record_133.txt
# ✅ Successfully uploaded: record_134.txt
# ✅ Successfully uploaded: record_135.txt
# ✅ Successfully uploaded: record_136.txt
# ✅ Successfully uploaded: record_137.txt
# ✅ Successfully uploaded: record_138.txt
# ✅ Successfully uploaded: record_139.txt
# ✅ Successfully uploaded: record_14.txt
# ✅ Successfully uploaded: record_140.txt
# ✅ Successfully uploaded: record_141.txt
# ✅ Successfully uploaded: record_142.txt
# ✅ Successfully uploaded: record_143.txt
# ✅ Successfully uploaded: record_144.txt
# ✅ Successfully uploaded: record_145.txt
# ✅ Successfully uploaded: record_146.txt
# ✅ Successfully uploaded: record_147.txt
# ✅ Successfully uploaded: record_148.txt
# ✅ Successfully uploaded: record_149.txt
# ✅ Successfully uploaded: record_15.txt
# ✅ Successfully uploaded: record_150.txt
# ✅ Successfully uploaded: record_151.txt
# ✅ Successfully uploaded: record_152.txt
# ✅ Successfully uploaded: record_153.txt
# ✅ Successfully uploaded: record_154.txt
# ✅ Successfully uploaded: record_155.txt
# ✅ Successfully uploaded: record_156.txt
# ✅ Successfully uploaded: record_157.txt
# ✅ Successfully uploaded: record_158.txt
# ✅ Successfully uploaded: record_159.txt
# ✅ Successfully uploaded: record_16.txt
# ✅ Successfully uploaded: record_160.txt
# ✅ Successfully uploaded: record_161.txt
# ✅ Successfully uploaded: record_162.txt
# ✅ Successfully uploaded: record_163.txt
# ✅ Successfully uploaded: record_164.txt
# ✅ Successfully uploaded: record_165.txt
# ✅ Successfully uploaded: record_166.txt
# ✅ Successfully uploaded: record_167.txt
# ✅ Successfully uploaded: record_168.txt
# ✅ Successfully uploaded: record_169.txt
# ✅ Successfully uploaded: record_17.txt
# ✅ Successfully uploaded: record_170.txt
# ✅ Successfully uploaded: record_171.txt
# ✅ Successfully uploaded: record_172.txt
# ✅ Successfully uploaded: record_173.txt
# ✅ Successfully uploaded: record_174.txt
# ✅ Successfully uploaded: record_175.txt
# ✅ Successfully uploaded: record_176.txt
# ✅ Successfully uploaded: record_177.txt
# ✅ Successfully uploaded: record_178.txt
# ✅ Successfully uploaded: record_179.txt
# ✅ Successfully uploaded: record_18.txt
# ✅ Successfully uploaded: record_180.txt
# ✅ Successfully uploaded: record_181.txt
# ✅ Successfully uploaded: record_182.txt
# ✅ Successfully uploaded: record_183.txt
# ✅ Successfully uploaded: record_184.txt
# ✅ Successfully uploaded: record_185.txt
# ✅ Successfully uploaded: record_186.txt
# ✅ Successfully uploaded: record_187.txt
# ✅ Successfully uploaded: record_188.txt
# ✅ Successfully uploaded: record_189.txt
# ✅ Successfully uploaded: record_19.txt
# ✅ Successfully uploaded: record_190.txt
# ✅ Successfully uploaded: record_191.txt
# ✅ Successfully uploaded: record_192.txt
# ✅ Successfully uploaded: record_193.txt
# ✅ Successfully uploaded: record_194.txt
# ✅ Successfully uploaded: record_195.txt
# ✅ Successfully uploaded: record_196.txt
# ✅ Successfully uploaded: record_197.txt
# ✅ Successfully uploaded: record_198.txt
# ✅ Successfully uploaded: record_199.txt
# ✅ Successfully uploaded: record_2.txt
# ✅ Successfully uploaded: record_20.txt
# ✅ Successfully uploaded: record_200.txt
# ✅ Successfully uploaded: record_201.txt
# ✅ Successfully uploaded: record_202.txt
# ✅ Successfully uploaded: record_203.txt
# ✅ Successfully uploaded: record_204.txt
# ✅ Successfully uploaded: record_205.txt
# ✅ Successfully uploaded: record_206.txt
# ✅ Successfully uploaded: record_207.txt
# ✅ Successfully uploaded: record_208.txt
# ✅ Successfully uploaded: record_209.txt
# ✅ Successfully uploaded: record_21.txt
# ✅ Successfully uploaded: record_210.txt
# ✅ Successfully uploaded: record_211.txt
# ✅ Successfully uploaded: record_212.txt
# ✅ Successfully uploaded: record_213.txt
# ✅ Successfully uploaded: record_214.txt
# ✅ Successfully uploaded: record_215.txt
# ✅ Successfully uploaded: record_216.txt
# ✅ Successfully uploaded: record_217.txt
# ✅ Successfully uploaded: record_218.txt
# ✅ Successfully uploaded: record_219.txt
# ✅ Successfully uploaded: record_22.txt
# ✅ Successfully uploaded: record_220.txt
# ✅ Successfully uploaded: record_221.txt
# ✅ Successfully uploaded: record_222.txt
# ✅ Successfully uploaded: record_223.txt
# ✅ Successfully uploaded: record_224.txt
# ✅ Successfully uploaded: record_225.txt
# ✅ Successfully uploaded: record_226.txt
# ✅ Successfully uploaded: record_227.txt
# ✅ Successfully uploaded: record_228.txt
# ✅ Successfully uploaded: record_229.txt
# ✅ Successfully uploaded: record_23.txt
# ✅ Successfully uploaded: record_230.txt
# ✅ Successfully uploaded: record_231.txt
# ✅ Successfully uploaded: record_232.txt
# ✅ Successfully uploaded: record_233.txt
# ✅ Successfully uploaded: record_234.txt
# ✅ Successfully uploaded: record_235.txt
# ✅ Successfully uploaded: record_236.txt
# ✅ Successfully uploaded: record_237.txt
# ✅ Successfully uploaded: record_238.txt
# ✅ Successfully uploaded: record_239.txt
# ✅ Successfully uploaded: record_24.txt
# ✅ Successfully uploaded: record_240.txt
# ✅ Successfully uploaded: record_241.txt
# ✅ Successfully uploaded: record_242.txt
# ✅ Successfully uploaded: record_243.txt
# ✅ Successfully uploaded: record_244.txt
# ✅ Successfully uploaded: record_245.txt
# ✅ Successfully uploaded: record_246.txt
# ✅ Successfully uploaded: record_247.txt
# ✅ Successfully uploaded: record_248.txt
# ✅ Successfully uploaded: record_249.txt
# ✅ Successfully uploaded: record_25.txt
# ✅ Successfully uploaded: record_250.txt
# ✅ Successfully uploaded: record_251.txt
# ✅ Successfully uploaded: record_252.txt
# ✅ Successfully uploaded: record_253.txt
# ✅ Successfully uploaded: record_254.txt
# ✅ Successfully uploaded: record_255.txt
# ✅ Successfully uploaded: record_256.txt
# ✅ Successfully uploaded: record_257.txt
# ✅ Successfully uploaded: record_258.txt
# ✅ Successfully uploaded: record_259.txt
# ✅ Successfully uploaded: record_26.txt
# ✅ Successfully uploaded: record_260.txt
# ✅ Successfully uploaded: record_261.txt
# ✅ Successfully uploaded: record_262.txt
# ✅ Successfully uploaded: record_263.txt
# ✅ Successfully uploaded: record_264.txt
# ✅ Successfully uploaded: record_265.txt
# ✅ Successfully uploaded: record_266.txt
# ✅ Successfully uploaded: record_267.txt
# ✅ Successfully uploaded: record_268.txt
# ✅ Successfully uploaded: record_269.txt
# ✅ Successfully uploaded: record_27.txt
# ✅ Successfully uploaded: record_270.txt
# ✅ Successfully uploaded: record_271.txt
# ✅ Successfully uploaded: record_272.txt
# ✅ Successfully uploaded: record_273.txt
# ✅ Successfully uploaded: record_274.txt
# ✅ Successfully uploaded: record_275.txt
# ✅ Successfully uploaded: record_276.txt
# ✅ Successfully uploaded: record_277.txt
# ✅ Successfully uploaded: record_278.txt
# ✅ Successfully uploaded: record_279.txt
# ✅ Successfully uploaded: record_28.txt
# ✅ Successfully uploaded: record_280.txt
# ✅ Successfully uploaded: record_281.txt
# ✅ Successfully uploaded: record_282.txt
# ✅ Successfully uploaded: record_283.txt
# ✅ Successfully uploaded: record_284.txt
# ✅ Successfully uploaded: record_285.txt
# ✅ Successfully uploaded: record_286.txt
# ✅ Successfully uploaded: record_287.txt
# ✅ Successfully uploaded: record_288.txt
# ✅ Successfully uploaded: record_289.txt
# ✅ Successfully uploaded: record_29.txt
# ✅ Successfully uploaded: record_290.txt
# ✅ Successfully uploaded: record_291.txt
# ✅ Successfully uploaded: record_292.txt
# ✅ Successfully uploaded: record_293.txt
# ✅ Successfully uploaded: record_294.txt
# ✅ Successfully uploaded: record_295.txt
# ✅ Successfully uploaded: record_296.txt
# ✅ Successfully uploaded: record_297.txt
# ✅ Successfully uploaded: record_298.txt
# ✅ Successfully uploaded: record_299.txt
# ✅ Successfully uploaded: record_3.txt
# ✅ Successfully uploaded: record_30.txt
# ✅ Successfully uploaded: record_300.txt
# ✅ Successfully uploaded: record_301.txt
# ✅ Successfully uploaded: record_302.txt
# ✅ Successfully uploaded: record_303.txt
# ✅ Successfully uploaded: record_304.txt
# ✅ Successfully uploaded: record_305.txt
# ✅ Successfully uploaded: record_306.txt
# ✅ Successfully uploaded: record_307.txt
# ✅ Successfully uploaded: record_308.txt
# ✅ Successfully uploaded: record_309.txt
# ✅ Successfully uploaded: record_31.txt
# ✅ Successfully uploaded: record_310.txt
# ✅ Successfully uploaded: record_311.txt
# ✅ Successfully uploaded: record_312.txt
# ✅ Successfully uploaded: record_313.txt
# ✅ Successfully uploaded: record_314.txt
# ✅ Successfully uploaded: record_315.txt
# ✅ Successfully uploaded: record_316.txt
# ✅ Successfully uploaded: record_317.txt
# ✅ Successfully uploaded: record_318.txt
# ✅ Successfully uploaded: record_319.txt
# ✅ Successfully uploaded: record_32.txt
# ✅ Successfully uploaded: record_320.txt
# ✅ Successfully uploaded: record_321.txt
# ✅ Successfully uploaded: record_322.txt
# ✅ Successfully uploaded: record_323.txt
# ✅ Successfully uploaded: record_324.txt
# ✅ Successfully uploaded: record_325.txt
# ✅ Successfully uploaded: record_326.txt
# ✅ Successfully uploaded: record_327.txt
# ✅ Successfully uploaded: record_328.txt
# ✅ Successfully uploaded: record_329.txt
# ✅ Successfully uploaded: record_33.txt
# ✅ Successfully uploaded: record_330.txt
# ✅ Successfully uploaded: record_331.txt
# ✅ Successfully uploaded: record_332.txt
# ✅ Successfully uploaded: record_333.txt
# ✅ Successfully uploaded: record_334.txt
# ✅ Successfully uploaded: record_335.txt
# ✅ Successfully uploaded: record_336.txt
# ✅ Successfully uploaded: record_337.txt
# ✅ Successfully uploaded: record_338.txt
# ✅ Successfully uploaded: record_339.txt
# ✅ Successfully uploaded: record_34.txt
# ✅ Successfully uploaded: record_340.txt
# ✅ Successfully uploaded: record_341.txt
# ✅ Successfully uploaded: record_342.txt
# ✅ Successfully uploaded: record_343.txt
# ✅ Successfully uploaded: record_344.txt
# ✅ Successfully uploaded: record_345.txt
# ✅ Successfully uploaded: record_346.txt
# ✅ Successfully uploaded: record_347.txt
# ✅ Successfully uploaded: record_348.txt
# ✅ Successfully uploaded: record_349.txt
# ✅ Successfully uploaded: record_35.txt
# ✅ Successfully uploaded: record_350.txt
# ✅ Successfully uploaded: record_351.txt
# ✅ Successfully uploaded: record_352.txt
# ✅ Successfully uploaded: record_353.txt
# ✅ Successfully uploaded: record_354.txt
# ✅ Successfully uploaded: record_355.txt
# ✅ Successfully uploaded: record_356.txt
# ✅ Successfully uploaded: record_357.txt
# ✅ Successfully uploaded: record_358.txt
# ✅ Successfully uploaded: record_359.txt
# ✅ Successfully uploaded: record_36.txt
# ✅ Successfully uploaded: record_360.txt
# ✅ Successfully uploaded: record_361.txt
# ✅ Successfully uploaded: record_362.txt
# ✅ Successfully uploaded: record_363.txt
# ✅ Successfully uploaded: record_364.txt
# ✅ Successfully uploaded: record_365.txt
# ✅ Successfully uploaded: record_366.txt
# ✅ Successfully uploaded: record_367.txt
# ✅ Successfully uploaded: record_368.txt
# ✅ Successfully uploaded: record_369.txt
# ✅ Successfully uploaded: record_37.txt
# ✅ Successfully uploaded: record_370.txt
# ✅ Successfully uploaded: record_371.txt
# ✅ Successfully uploaded: record_372.txt
# ✅ Successfully uploaded: record_373.txt
# ✅ Successfully uploaded: record_374.txt
# ✅ Successfully uploaded: record_375.txt
# ✅ Successfully uploaded: record_376.txt
# ✅ Successfully uploaded: record_377.txt
# ✅ Successfully uploaded: record_378.txt
# ✅ Successfully uploaded: record_379.txt
# ✅ Successfully uploaded: record_38.txt
# ✅ Successfully uploaded: record_380.txt
# ✅ Successfully uploaded: record_381.txt
# ✅ Successfully uploaded: record_382.txt
# ✅ Successfully uploaded: record_383.txt
# ✅ Successfully uploaded: record_384.txt
# ✅ Successfully uploaded: record_385.txt
# ✅ Successfully uploaded: record_386.txt
# ✅ Successfully uploaded: record_387.txt
# ✅ Successfully uploaded: record_388.txt
# ✅ Successfully uploaded: record_389.txt
# ✅ Successfully uploaded: record_39.txt
# ✅ Successfully uploaded: record_390.txt
# ✅ Successfully uploaded: record_391.txt
# ✅ Successfully uploaded: record_392.txt
# ✅ Successfully uploaded: record_393.txt
# ✅ Successfully uploaded: record_394.txt
# ✅ Successfully uploaded: record_395.txt
# ✅ Successfully uploaded: record_396.txt
# ✅ Successfully uploaded: record_397.txt
# ✅ Successfully uploaded: record_398.txt
# ✅ Successfully uploaded: record_399.txt
# ✅ Successfully uploaded: record_4.txt
# ✅ Successfully uploaded: record_40.txt
# ✅ Successfully uploaded: record_400.txt
# ✅ Successfully uploaded: record_401.txt
# ✅ Successfully uploaded: record_402.txt
# ✅ Successfully uploaded: record_403.txt
# ✅ Successfully uploaded: record_404.txt
# ✅ Successfully uploaded: record_405.txt
# ✅ Successfully uploaded: record_406.txt
# ✅ Successfully uploaded: record_407.txt
# ✅ Successfully uploaded: record_408.txt
# ✅ Successfully uploaded: record_409.txt
# ✅ Successfully uploaded: record_41.txt
# ✅ Successfully uploaded: record_410.txt
# ✅ Successfully uploaded: record_411.txt
# ✅ Successfully uploaded: record_412.txt
# ✅ Successfully uploaded: record_413.txt
# ✅ Successfully uploaded: record_414.txt
# ✅ Successfully uploaded: record_415.txt
# ✅ Successfully uploaded: record_416.txt
# ✅ Successfully uploaded: record_417.txt
# ✅ Successfully uploaded: record_418.txt
# ✅ Successfully uploaded: record_419.txt
# ✅ Successfully uploaded: record_42.txt
# ✅ Successfully uploaded: record_420.txt
# ✅ Successfully uploaded: record_421.txt
# ✅ Successfully uploaded: record_422.txt
# ✅ Successfully uploaded: record_423.txt
# ✅ Successfully uploaded: record_424.txt
# ✅ Successfully uploaded: record_425.txt
# ✅ Successfully uploaded: record_426.txt
# ✅ Successfully uploaded: record_427.txt
# ✅ Successfully uploaded: record_428.txt
# ✅ Successfully uploaded: record_429.txt
# ✅ Successfully uploaded: record_43.txt
# ✅ Successfully uploaded: record_430.txt
# ✅ Successfully uploaded: record_431.txt
# ✅ Successfully uploaded: record_432.txt
# ✅ Successfully uploaded: record_433.txt
# ✅ Successfully uploaded: record_434.txt
# ✅ Successfully uploaded: record_435.txt
# ✅ Successfully uploaded: record_436.txt
# ✅ Successfully uploaded: record_437.txt
# ✅ Successfully uploaded: record_438.txt
# ✅ Successfully uploaded: record_439.txt
# ✅ Successfully uploaded: record_44.txt
# ✅ Successfully uploaded: record_440.txt
# ✅ Successfully uploaded: record_441.txt
# ✅ Successfully uploaded: record_442.txt
# ✅ Successfully uploaded: record_443.txt
# ✅ Successfully uploaded: record_444.txt
# ✅ Successfully uploaded: record_445.txt
# ✅ Successfully uploaded: record_446.txt
# ✅ Successfully uploaded: record_447.txt
# ✅ Successfully uploaded: record_448.txt
# ✅ Successfully uploaded: record_449.txt
# ✅ Successfully uploaded: record_45.txt
# ✅ Successfully uploaded: record_450.txt
# ✅ Successfully uploaded: record_451.txt
# ✅ Successfully uploaded: record_452.txt
# ✅ Successfully uploaded: record_453.txt
# ✅ Successfully uploaded: record_454.txt
# ✅ Successfully uploaded: record_455.txt
# ✅ Successfully uploaded: record_456.txt
# ✅ Successfully uploaded: record_457.txt
# ✅ Successfully uploaded: record_458.txt
# ✅ Successfully uploaded: record_459.txt
# ✅ Successfully uploaded: record_46.txt
# ✅ Successfully uploaded: record_460.txt
# ✅ Successfully uploaded: record_461.txt
# ✅ Successfully uploaded: record_462.txt
# ✅ Successfully uploaded: record_463.txt
# ✅ Successfully uploaded: record_464.txt
# ✅ Successfully uploaded: record_465.txt
# ✅ Successfully uploaded: record_466.txt
# ✅ Successfully uploaded: record_467.txt
# ✅ Successfully uploaded: record_468.txt
# ✅ Successfully uploaded: record_469.txt
# ✅ Successfully uploaded: record_47.txt
# ✅ Successfully uploaded: record_470.txt
# ✅ Successfully uploaded: record_471.txt
# ✅ Successfully uploaded: record_472.txt
# ✅ Successfully uploaded: record_473.txt
# ✅ Successfully uploaded: record_474.txt
# ✅ Successfully uploaded: record_475.txt
# ✅ Successfully uploaded: record_476.txt
# ✅ Successfully uploaded: record_477.txt
# ✅ Successfully uploaded: record_478.txt
# ✅ Successfully uploaded: record_479.txt
# ✅ Successfully uploaded: record_48.txt
# ✅ Successfully uploaded: record_480.txt
# ✅ Successfully uploaded: record_481.txt
# ✅ Successfully uploaded: record_482.txt
# ✅ Successfully uploaded: record_483.txt
# ✅ Successfully uploaded: record_484.txt
# ✅ Successfully uploaded: record_485.txt
# ✅ Successfully uploaded: record_486.txt
# ✅ Successfully uploaded: record_487.txt
# ✅ Successfully uploaded: record_488.txt
# ✅ Successfully uploaded: record_489.txt
# ✅ Successfully uploaded: record_49.txt
# ✅ Successfully uploaded: record_490.txt
# ✅ Successfully uploaded: record_491.txt
# ✅ Successfully uploaded: record_492.txt
# ✅ Successfully uploaded: record_493.txt
# ✅ Successfully uploaded: record_494.txt
# ✅ Successfully uploaded: record_495.txt
# ✅ Successfully uploaded: record_496.txt
# ✅ Successfully uploaded: record_497.txt
# ✅ Successfully uploaded: record_498.txt
# ✅ Successfully uploaded: record_499.txt
# ✅ Successfully uploaded: record_5.txt
# ✅ Successfully uploaded: record_50.txt
# ✅ Successfully uploaded: record_500.txt
# ✅ Successfully uploaded: record_501.txt
# ✅ Successfully uploaded: record_502.txt
# ✅ Successfully uploaded: record_503.txt
# ✅ Successfully uploaded: record_504.txt
# ✅ Successfully uploaded: record_505.txt
# ✅ Successfully uploaded: record_506.txt
# ✅ Successfully uploaded: record_507.txt
# ✅ Successfully uploaded: record_508.txt
# ✅ Successfully uploaded: record_509.txt
# ✅ Successfully uploaded: record_51.txt
# ✅ Successfully uploaded: record_510.txt
# ✅ Successfully uploaded: record_511.txt
# ✅ Successfully uploaded: record_512.txt
# ✅ Successfully uploaded: record_513.txt
# ✅ Successfully uploaded: record_514.txt
# ✅ Successfully uploaded: record_515.txt
# ✅ Successfully uploaded: record_516.txt
# ✅ Successfully uploaded: record_517.txt
# ✅ Successfully uploaded: record_518.txt
# ✅ Successfully uploaded: record_519.txt
# ✅ Successfully uploaded: record_52.txt
# ✅ Successfully uploaded: record_520.txt
# ✅ Successfully uploaded: record_521.txt
# ✅ Successfully uploaded: record_522.txt
# ✅ Successfully uploaded: record_523.txt
# ✅ Successfully uploaded: record_524.txt
# ✅ Successfully uploaded: record_525.txt
# ✅ Successfully uploaded: record_526.txt
# ✅ Successfully uploaded: record_527.txt
# ✅ Successfully uploaded: record_528.txt
# ✅ Successfully uploaded: record_529.txt
# ✅ Successfully uploaded: record_53.txt
# ✅ Successfully uploaded: record_530.txt
# ✅ Successfully uploaded: record_531.txt
# ✅ Successfully uploaded: record_532.txt
# ✅ Successfully uploaded: record_533.txt
# ✅ Successfully uploaded: record_534.txt
# ✅ Successfully uploaded: record_535.txt
# ✅ Successfully uploaded: record_536.txt
# ✅ Successfully uploaded: record_537.txt
# ✅ Successfully uploaded: record_538.txt
# ✅ Successfully uploaded: record_539.txt
# ✅ Successfully uploaded: record_54.txt
# ✅ Successfully uploaded: record_540.txt
# ✅ Successfully uploaded: record_541.txt
# ✅ Successfully uploaded: record_542.txt
# ✅ Successfully uploaded: record_543.txt
# ✅ Successfully uploaded: record_544.txt
# ✅ Successfully uploaded: record_545.txt
# ✅ Successfully uploaded: record_546.txt
# ✅ Successfully uploaded: record_547.txt
# ✅ Successfully uploaded: record_548.txt
# ✅ Successfully uploaded: record_549.txt
# ✅ Successfully uploaded: record_55.txt
# ✅ Successfully uploaded: record_550.txt
# ✅ Successfully uploaded: record_551.txt
# ✅ Successfully uploaded: record_552.txt
# ✅ Successfully uploaded: record_553.txt
# ✅ Successfully uploaded: record_554.txt
# ✅ Successfully uploaded: record_555.txt
# ✅ Successfully uploaded: record_556.txt
# ✅ Successfully uploaded: record_557.txt
# ✅ Successfully uploaded: record_558.txt
# ✅ Successfully uploaded: record_559.txt
# ✅ Successfully uploaded: record_56.txt
# ✅ Successfully uploaded: record_560.txt
# ✅ Successfully uploaded: record_561.txt
# ✅ Successfully uploaded: record_562.txt
# ✅ Successfully uploaded: record_563.txt
# ✅ Successfully uploaded: record_564.txt
# ✅ Successfully uploaded: record_565.txt
# ✅ Successfully uploaded: record_566.txt
# ✅ Successfully uploaded: record_567.txt
# ✅ Successfully uploaded: record_568.txt
# ✅ Successfully uploaded: record_569.txt
# ✅ Successfully uploaded: record_57.txt
# ✅ Successfully uploaded: record_570.txt
# ✅ Successfully uploaded: record_571.txt
# ✅ Successfully uploaded: record_572.txt
# ✅ Successfully uploaded: record_573.txt
# ✅ Successfully uploaded: record_574.txt
# ✅ Successfully uploaded: record_575.txt
# ✅ Successfully uploaded: record_576.txt
# ✅ Successfully uploaded: record_577.txt
# ✅ Successfully uploaded: record_578.txt
# ✅ Successfully uploaded: record_579.txt
# ✅ Successfully uploaded: record_58.txt
# ✅ Successfully uploaded: record_580.txt
# ✅ Successfully uploaded: record_581.txt
# ✅ Successfully uploaded: record_582.txt
# ✅ Successfully uploaded: record_583.txt
# ✅ Successfully uploaded: record_584.txt
# ✅ Successfully uploaded: record_585.txt
# ✅ Successfully uploaded: record_586.txt
# ✅ Successfully uploaded: record_587.txt
# ✅ Successfully uploaded: record_588.txt
# ✅ Successfully uploaded: record_589.txt
# ✅ Successfully uploaded: record_59.txt
# ✅ Successfully uploaded: record_590.txt
# ✅ Successfully uploaded: record_591.txt
# ✅ Successfully uploaded: record_592.txt
# ✅ Successfully uploaded: record_593.txt
# ✅ Successfully uploaded: record_594.txt
# ✅ Successfully uploaded: record_595.txt
# ✅ Successfully uploaded: record_596.txt
# ✅ Successfully uploaded: record_597.txt
# ✅ Successfully uploaded: record_598.txt
# ✅ Successfully uploaded: record_599.txt
# ✅ Successfully uploaded: record_6.txt
# ✅ Successfully uploaded: record_60.txt
# ✅ Successfully uploaded: record_600.txt
# ✅ Successfully uploaded: record_601.txt
# ✅ Successfully uploaded: record_602.txt
# ✅ Successfully uploaded: record_603.txt
# ✅ Successfully uploaded: record_604.txt
# ✅ Successfully uploaded: record_605.txt
# ✅ Successfully uploaded: record_606.txt
# ✅ Successfully uploaded: record_607.txt
# ✅ Successfully uploaded: record_608.txt
# ✅ Successfully uploaded: record_609.txt
# ✅ Successfully uploaded: record_61.txt
# ✅ Successfully uploaded: record_610.txt
# ✅ Successfully uploaded: record_611.txt
# ✅ Successfully uploaded: record_612.txt
# ✅ Successfully uploaded: record_613.txt
# ✅ Successfully uploaded: record_614.txt
# ✅ Successfully uploaded: record_615.txt
# ✅ Successfully uploaded: record_616.txt
# ✅ Successfully uploaded: record_617.txt
# ✅ Successfully uploaded: record_618.txt
# ✅ Successfully uploaded: record_619.txt
# ✅ Successfully uploaded: record_62.txt
# ✅ Successfully uploaded: record_620.txt
# ✅ Successfully uploaded: record_621.txt
# ✅ Successfully uploaded: record_622.txt
# ✅ Successfully uploaded: record_623.txt
# ✅ Successfully uploaded: record_624.txt
# ✅ Successfully uploaded: record_625.txt
# ✅ Successfully uploaded: record_626.txt
# ✅ Successfully uploaded: record_627.txt
# ✅ Successfully uploaded: record_628.txt
# ✅ Successfully uploaded: record_629.txt
# ✅ Successfully uploaded: record_63.txt
# ✅ Successfully uploaded: record_630.txt
# ✅ Successfully uploaded: record_631.txt
# ✅ Successfully uploaded: record_632.txt
# ✅ Successfully uploaded: record_633.txt
# ✅ Successfully uploaded: record_634.txt
# ✅ Successfully uploaded: record_635.txt
# ✅ Successfully uploaded: record_636.txt
# ✅ Successfully uploaded: record_637.txt
# ✅ Successfully uploaded: record_638.txt
# ✅ Successfully uploaded: record_639.txt
# ✅ Successfully uploaded: record_64.txt
# ✅ Successfully uploaded: record_640.txt
# ✅ Successfully uploaded: record_641.txt
# ✅ Successfully uploaded: record_642.txt
# ✅ Successfully uploaded: record_643.txt
# ✅ Successfully uploaded: record_644.txt
# ✅ Successfully uploaded: record_645.txt
# ✅ Successfully uploaded: record_646.txt
# ✅ Successfully uploaded: record_647.txt
# ✅ Successfully uploaded: record_648.txt
# ✅ Successfully uploaded: record_649.txt
# ✅ Successfully uploaded: record_65.txt
# ✅ Successfully uploaded: record_650.txt
# ✅ Successfully uploaded: record_651.txt
# ✅ Successfully uploaded: record_652.txt
# ✅ Successfully uploaded: record_653.txt
# ✅ Successfully uploaded: record_654.txt
# ✅ Successfully uploaded: record_655.txt
# ✅ Successfully uploaded: record_656.txt
# ✅ Successfully uploaded: record_657.txt
# ✅ Successfully uploaded: record_658.txt
# ✅ Successfully uploaded: record_659.txt
# ✅ Successfully uploaded: record_66.txt
# ✅ Successfully uploaded: record_660.txt
# ✅ Successfully uploaded: record_661.txt
# ✅ Successfully uploaded: record_662.txt
# ✅ Successfully uploaded: record_663.txt
# ✅ Successfully uploaded: record_664.txt
# ✅ Successfully uploaded: record_665.txt
# ✅ Successfully uploaded: record_666.txt
# ✅ Successfully uploaded: record_667.txt
# ✅ Successfully uploaded: record_668.txt
# ✅ Successfully uploaded: record_669.txt
# ✅ Successfully uploaded: record_67.txt
# ✅ Successfully uploaded: record_670.txt
# ✅ Successfully uploaded: record_671.txt
# ✅ Successfully uploaded: record_672.txt
# ✅ Successfully uploaded: record_673.txt
# ✅ Successfully uploaded: record_674.txt
# ✅ Successfully uploaded: record_675.txt
# ✅ Successfully uploaded: record_676.txt
# ✅ Successfully uploaded: record_677.txt
# ✅ Successfully uploaded: record_678.txt
# ✅ Successfully uploaded: record_679.txt
# ✅ Successfully uploaded: record_68.txt
# ✅ Successfully uploaded: record_680.txt
# ✅ Successfully uploaded: record_681.txt
# ✅ Successfully uploaded: record_682.txt
# ✅ Successfully uploaded: record_683.txt
# ✅ Successfully uploaded: record_684.txt
# ✅ Successfully uploaded: record_685.txt
# ✅ Successfully uploaded: record_686.txt
# ✅ Successfully uploaded: record_687.txt
# ✅ Successfully uploaded: record_688.txt
# ✅ Successfully uploaded: record_689.txt
# ✅ Successfully uploaded: record_69.txt
# ✅ Successfully uploaded: record_690.txt
# ✅ Successfully uploaded: record_691.txt
# ✅ Successfully uploaded: record_692.txt
# ✅ Successfully uploaded: record_693.txt
# ✅ Successfully uploaded: record_694.txt
# ✅ Successfully uploaded: record_695.txt
# ✅ Successfully uploaded: record_696.txt
# ✅ Successfully uploaded: record_697.txt
# ✅ Successfully uploaded: record_698.txt
# ✅ Successfully uploaded: record_699.txt
# ✅ Successfully uploaded: record_7.txt
# ✅ Successfully uploaded: record_70.txt
# ✅ Successfully uploaded: record_700.txt
# ✅ Successfully uploaded: record_701.txt
# ✅ Successfully uploaded: record_702.txt
# ✅ Successfully uploaded: record_703.txt
# ✅ Successfully uploaded: record_704.txt
# ✅ Successfully uploaded: record_705.txt
# ✅ Successfully uploaded: record_706.txt
# ✅ Successfully uploaded: record_707.txt
# ✅ Successfully uploaded: record_708.txt
# ✅ Successfully uploaded: record_709.txt
# ✅ Successfully uploaded: record_71.txt
# ✅ Successfully uploaded: record_710.txt
# ✅ Successfully uploaded: record_711.txt
# ✅ Successfully uploaded: record_712.txt
# ✅ Successfully uploaded: record_713.txt
# ✅ Successfully uploaded: record_714.txt
# ✅ Successfully uploaded: record_715.txt
# ✅ Successfully uploaded: record_716.txt
# ✅ Successfully uploaded: record_717.txt
# ✅ Successfully uploaded: record_718.txt
# ✅ Successfully uploaded: record_719.txt
# ✅ Successfully uploaded: record_72.txt
# ✅ Successfully uploaded: record_720.txt
# ✅ Successfully uploaded: record_721.txt
# ✅ Successfully uploaded: record_722.txt
# ✅ Successfully uploaded: record_723.txt
# ✅ Successfully uploaded: record_724.txt
# ✅ Successfully uploaded: record_725.txt
# ✅ Successfully uploaded: record_726.txt
# ✅ Successfully uploaded: record_727.txt
# ✅ Successfully uploaded: record_728.txt
# ✅ Successfully uploaded: record_729.txt
# ✅ Successfully uploaded: record_73.txt
# ✅ Successfully uploaded: record_730.txt
# ✅ Successfully uploaded: record_731.txt
# ✅ Successfully uploaded: record_732.txt
# ✅ Successfully uploaded: record_733.txt
# ✅ Successfully uploaded: record_734.txt
# ✅ Successfully uploaded: record_735.txt
# ✅ Successfully uploaded: record_736.txt
# ✅ Successfully uploaded: record_737.txt
# ✅ Successfully uploaded: record_738.txt
# ✅ Successfully uploaded: record_739.txt
# ✅ Successfully uploaded: record_74.txt
# ✅ Successfully uploaded: record_740.txt
# ✅ Successfully uploaded: record_741.txt
# ✅ Successfully uploaded: record_742.txt
# ✅ Successfully uploaded: record_743.txt
# ✅ Successfully uploaded: record_744.txt
# ✅ Successfully uploaded: record_745.txt
# ✅ Successfully uploaded: record_746.txt
# ✅ Successfully uploaded: record_747.txt
# ✅ Successfully uploaded: record_748.txt
# ✅ Successfully uploaded: record_749.txt
# ✅ Successfully uploaded: record_75.txt
# ✅ Successfully uploaded: record_750.txt
# ✅ Successfully uploaded: record_751.txt
# ✅ Successfully uploaded: record_752.txt
# ✅ Successfully uploaded: record_753.txt
# ✅ Successfully uploaded: record_754.txt
# ✅ Successfully uploaded: record_755.txt
# ✅ Successfully uploaded: record_756.txt
# ✅ Successfully uploaded: record_757.txt
# ✅ Successfully uploaded: record_758.txt
# ✅ Successfully uploaded: record_759.txt
# ✅ Successfully uploaded: record_76.txt
# ✅ Successfully uploaded: record_760.txt
# ✅ Successfully uploaded: record_761.txt
# ✅ Successfully uploaded: record_762.txt
# ✅ Successfully uploaded: record_763.txt
# ✅ Successfully uploaded: record_764.txt
# ✅ Successfully uploaded: record_765.txt
# ✅ Successfully uploaded: record_766.txt
# ✅ Successfully uploaded: record_767.txt
# ✅ Successfully uploaded: record_768.txt
# ✅ Successfully uploaded: record_769.txt
# ✅ Successfully uploaded: record_77.txt
# ✅ Successfully uploaded: record_770.txt
# ✅ Successfully uploaded: record_771.txt
# ✅ Successfully uploaded: record_772.txt
# ✅ Successfully uploaded: record_773.txt
# ✅ Successfully uploaded: record_774.txt
# ✅ Successfully uploaded: record_775.txt
# ✅ Successfully uploaded: record_776.txt
# ✅ Successfully uploaded: record_777.txt
# ✅ Successfully uploaded: record_778.txt
# ✅ Successfully uploaded: record_779.txt
# ✅ Successfully uploaded: record_78.txt
# ✅ Successfully uploaded: record_780.txt
# ✅ Successfully uploaded: record_781.txt
# ✅ Successfully uploaded: record_782.txt
# ✅ Successfully uploaded: record_783.txt
# ✅ Successfully uploaded: record_784.txt
# ✅ Successfully uploaded: record_785.txt
# ✅ Successfully uploaded: record_786.txt
# ✅ Successfully uploaded: record_787.txt
# ✅ Successfully uploaded: record_788.txt
# ✅ Successfully uploaded: record_789.txt
# ✅ Successfully uploaded: record_79.txt
# ✅ Successfully uploaded: record_790.txt
# ✅ Successfully uploaded: record_791.txt
# ✅ Successfully uploaded: record_792.txt
# ✅ Successfully uploaded: record_793.txt
# ✅ Successfully uploaded: record_794.txt
# ✅ Successfully uploaded: record_795.txt
# ✅ Successfully uploaded: record_796.txt
# ✅ Successfully uploaded: record_797.txt
# ✅ Successfully uploaded: record_798.txt
# ✅ Successfully uploaded: record_799.txt
# ✅ Successfully uploaded: record_8.txt
# ✅ Successfully uploaded: record_80.txt
# ✅ Successfully uploaded: record_800.txt
# ✅ Successfully uploaded: record_801.txt
# ✅ Successfully uploaded: record_802.txt
# ✅ Successfully uploaded: record_803.txt
# ✅ Successfully uploaded: record_804.txt
# ✅ Successfully uploaded: record_805.txt
# ✅ Successfully uploaded: record_806.txt
# ✅ Successfully uploaded: record_807.txt
# ✅ Successfully uploaded: record_808.txt
# ✅ Successfully uploaded: record_809.txt
# ✅ Successfully uploaded: record_81.txt
# ✅ Successfully uploaded: record_810.txt
# ✅ Successfully uploaded: record_811.txt
# ✅ Successfully uploaded: record_812.txt
# ✅ Successfully uploaded: record_813.txt
# ✅ Successfully uploaded: record_814.txt
# ✅ Successfully uploaded: record_815.txt
# ✅ Successfully uploaded: record_816.txt
# ✅ Successfully uploaded: record_817.txt
# ✅ Successfully uploaded: record_818.txt
# ✅ Successfully uploaded: record_819.txt
# ✅ Successfully uploaded: record_82.txt
# ✅ Successfully uploaded: record_820.txt
# ✅ Successfully uploaded: record_821.txt
# ✅ Successfully uploaded: record_822.txt
# ✅ Successfully uploaded: record_823.txt
# ✅ Successfully uploaded: record_824.txt
# ✅ Successfully uploaded: record_825.txt
# ✅ Successfully uploaded: record_826.txt
# ✅ Successfully uploaded: record_827.txt
# ✅ Successfully uploaded: record_828.txt
# ✅ Successfully uploaded: record_829.txt
# ✅ Successfully uploaded: record_83.txt
# ✅ Successfully uploaded: record_830.txt
# ✅ Successfully uploaded: record_831.txt
# ✅ Successfully uploaded: record_832.txt
# ✅ Successfully uploaded: record_833.txt
# ✅ Successfully uploaded: record_834.txt
# ✅ Successfully uploaded: record_835.txt
# ✅ Successfully uploaded: record_836.txt
# ✅ Successfully uploaded: record_837.txt
# ✅ Successfully uploaded: record_838.txt
# ✅ Successfully uploaded: record_839.txt
# ✅ Successfully uploaded: record_84.txt
# ✅ Successfully uploaded: record_840.txt
# ✅ Successfully uploaded: record_841.txt
# ✅ Successfully uploaded: record_842.txt
# ✅ Successfully uploaded: record_843.txt
# ✅ Successfully uploaded: record_844.txt
# ✅ Successfully uploaded: record_845.txt
# ✅ Successfully uploaded: record_846.txt
# ✅ Successfully uploaded: record_847.txt
# ✅ Successfully uploaded: record_848.txt
# ✅ Successfully uploaded: record_849.txt
# ✅ Successfully uploaded: record_85.txt
# ✅ Successfully uploaded: record_850.txt
# ✅ Successfully uploaded: record_851.txt
# ✅ Successfully uploaded: record_852.txt
# ✅ Successfully uploaded: record_853.txt
# ✅ Successfully uploaded: record_854.txt
# ✅ Successfully uploaded: record_855.txt
# ✅ Successfully uploaded: record_856.txt
# ✅ Successfully uploaded: record_857.txt
# ✅ Successfully uploaded: record_858.txt
# ✅ Successfully uploaded: record_859.txt
# ✅ Successfully uploaded: record_86.txt
# ✅ Successfully uploaded: record_860.txt
# ✅ Successfully uploaded: record_861.txt
# ✅ Successfully uploaded: record_862.txt
# ✅ Successfully uploaded: record_863.txt
# ✅ Successfully uploaded: record_864.txt
# ✅ Successfully uploaded: record_865.txt
# ✅ Successfully uploaded: record_866.txt
# ✅ Successfully uploaded: record_867.txt
# ✅ Successfully uploaded: record_868.txt
# ✅ Successfully uploaded: record_869.txt
# ✅ Successfully uploaded: record_87.txt
# ✅ Successfully uploaded: record_870.txt
# ✅ Successfully uploaded: record_871.txt
# ✅ Successfully uploaded: record_872.txt
# ✅ Successfully uploaded: record_873.txt
# ✅ Successfully uploaded: record_874.txt
# ✅ Successfully uploaded: record_875.txt
# ✅ Successfully uploaded: record_876.txt
# ✅ Successfully uploaded: record_877.txt
# ✅ Successfully uploaded: record_878.txt
# ✅ Successfully uploaded: record_879.txt
# ✅ Successfully uploaded: record_88.txt
# ✅ Successfully uploaded: record_880.txt
# ✅ Successfully uploaded: record_881.txt
# ✅ Successfully uploaded: record_882.txt
# ✅ Successfully uploaded: record_883.txt
# ✅ Successfully uploaded: record_884.txt
# ✅ Successfully uploaded: record_885.txt
# ✅ Successfully uploaded: record_886.txt
# ✅ Successfully uploaded: record_887.txt
# ✅ Successfully uploaded: record_888.txt
# ✅ Successfully uploaded: record_889.txt
# ✅ Successfully uploaded: record_89.txt
# ✅ Successfully uploaded: record_890.txt
# ✅ Successfully uploaded: record_891.txt
# ✅ Successfully uploaded: record_892.txt
# ✅ Successfully uploaded: record_893.txt
# ✅ Successfully uploaded: record_894.txt
# ✅ Successfully uploaded: record_895.txt
# ✅ Successfully uploaded: record_896.txt
# ✅ Successfully uploaded: record_897.txt
# ✅ Successfully uploaded: record_898.txt
# ✅ Successfully uploaded: record_899.txt
# ✅ Successfully uploaded: record_9.txt
# ✅ Successfully uploaded: record_90.txt
# ✅ Successfully uploaded: record_900.txt
# ✅ Successfully uploaded: record_901.txt
# ✅ Successfully uploaded: record_902.txt
# ✅ Successfully uploaded: record_903.txt
# ✅ Successfully uploaded: record_904.txt
# ✅ Successfully uploaded: record_905.txt
# ✅ Successfully uploaded: record_906.txt
# ✅ Successfully uploaded: record_907.txt
# ✅ Successfully uploaded: record_908.txt
# ✅ Successfully uploaded: record_909.txt
# ✅ Successfully uploaded: record_91.txt
# ✅ Successfully uploaded: record_910.txt
# ✅ Successfully uploaded: record_911.txt
# ✅ Successfully uploaded: record_912.txt
# ✅ Successfully uploaded: record_913.txt
# ✅ Successfully uploaded: record_914.txt
# ✅ Successfully uploaded: record_915.txt
# ✅ Successfully uploaded: record_916.txt
# ✅ Successfully uploaded: record_917.txt
# ✅ Successfully uploaded: record_918.txt
# ✅ Successfully uploaded: record_919.txt
# ✅ Successfully uploaded: record_92.txt
# ✅ Successfully uploaded: record_920.txt
# ✅ Successfully uploaded: record_921.txt
# ✅ Successfully uploaded: record_922.txt
# ✅ Successfully uploaded: record_923.txt
# ✅ Successfully uploaded: record_924.txt
# ✅ Successfully uploaded: record_925.txt
# ✅ Successfully uploaded: record_926.txt
# ✅ Successfully uploaded: record_927.txt
# ✅ Successfully uploaded: record_928.txt
# ✅ Successfully uploaded: record_929.txt
# ✅ Successfully uploaded: record_93.txt
# ✅ Successfully uploaded: record_930.txt
# ✅ Successfully uploaded: record_931.txt
# ✅ Successfully uploaded: record_932.txt
# ✅ Successfully uploaded: record_933.txt
# ✅ Successfully uploaded: record_934.txt
# ✅ Successfully uploaded: record_935.txt
# ✅ Successfully uploaded: record_936.txt
# ✅ Successfully uploaded: record_937.txt
# ✅ Successfully uploaded: record_938.txt
# ✅ Successfully uploaded: record_939.txt
# ✅ Successfully uploaded: record_94.txt
# ✅ Successfully uploaded: record_940.txt
# ✅ Successfully uploaded: record_941.txt
# ✅ Successfully uploaded: record_942.txt
# ✅ Successfully uploaded: record_943.txt
# ✅ Successfully uploaded: record_944.txt
# ✅ Successfully uploaded: record_945.txt
# ✅ Successfully uploaded: record_946.txt
# ✅ Successfully uploaded: record_947.txt
# ✅ Successfully uploaded: record_948.txt
# ✅ Successfully uploaded: record_949.txt
# ✅ Successfully uploaded: record_95.txt
# ✅ Successfully uploaded: record_950.txt
# ✅ Successfully uploaded: record_951.txt
# ✅ Successfully uploaded: record_952.txt
# ✅ Successfully uploaded: record_953.txt
# ✅ Successfully uploaded: record_954.txt
# ✅ Successfully uploaded: record_955.txt
# ✅ Successfully uploaded: record_956.txt
# ✅ Successfully uploaded: record_957.txt
# ✅ Successfully uploaded: record_958.txt
# ✅ Successfully uploaded: record_959.txt
# ✅ Successfully uploaded: record_96.txt
# ✅ Successfully uploaded: record_960.txt
# ✅ Successfully uploaded: record_961.txt
# ✅ Successfully uploaded: record_962.txt
# ✅ Successfully uploaded: record_963.txt
# ✅ Successfully uploaded: record_964.txt
# ✅ Successfully uploaded: record_965.txt
# ✅ Successfully uploaded: record_966.txt
# ✅ Successfully uploaded: record_967.txt
# ✅ Successfully uploaded: record_968.txt
# ✅ Successfully uploaded: record_969.txt
# ✅ Successfully uploaded: record_97.txt
# ✅ Successfully uploaded: record_970.txt
# ✅ Successfully uploaded: record_971.txt
# ✅ Successfully uploaded: record_972.txt
# ✅ Successfully uploaded: record_973.txt
# ✅ Successfully uploaded: record_974.txt
# ✅ Successfully uploaded: record_975.txt
# ✅ Successfully uploaded: record_976.txt
# ✅ Successfully uploaded: record_977.txt
# ✅ Successfully uploaded: record_978.txt
# ✅ Successfully uploaded: record_979.txt
# ✅ Successfully uploaded: record_98.txt
# ✅ Successfully uploaded: record_980.txt
# ✅ Successfully uploaded: record_981.txt
# ✅ Successfully uploaded: record_982.txt
# ✅ Successfully uploaded: record_983.txt
# ✅ Successfully uploaded: record_984.txt
# ✅ Successfully uploaded: record_985.txt
# ✅ Successfully uploaded: record_986.txt
# ✅ Successfully uploaded: record_987.txt
# ✅ Successfully uploaded: record_988.txt
# ✅ Successfully uploaded: record_989.txt
# ✅ Successfully uploaded: record_99.txt
# ✅ Successfully uploaded: record_990.txt
# ✅ Successfully uploaded: record_991.txt
# ✅ Successfully uploaded: record_992.txt
# ✅ Successfully uploaded: record_993.txt
# ✅ Successfully uploaded: record_994.txt
# ✅ Successfully uploaded: record_995.txt
# ✅ Successfully uploaded: record_996.txt
# ✅ Successfully uploaded: record_997.txt
# ✅ Successfully uploaded: record_998.txt
# ✅ Successfully uploaded: record_999.txt
# 🎉 All files uploaded successfully!

# %%
# Chunking the text files and preparing for Embedding

import requests

# Set FastAPI Base URL
API_URL = "http://127.0.0.1:5000/api/v1/data/process"
PROJECT_ID = "12"  # Change this to the actual project ID

# Processing Parameters
CHUNK_SIZE = 15000  
OVERLAP_SIZE = 0 
DO_RESET = 1  # Set to 1 to remove old chunks before processing

def process_uploaded_files():
    """Triggers processing of all uploaded files for a given project."""
    url = f"{API_URL}/{PROJECT_ID}"

    payload = {
        "chunk_size": CHUNK_SIZE,
        "overlap_size": OVERLAP_SIZE,
        "do_reset": DO_RESET
    }

    print(f"📂 Processing files for Project ID: {PROJECT_ID} with overlap {OVERLAP_SIZE} bytes...")
    response = requests.post(url, json=payload)

    if response.status_code == 200:
        print("✅ Successfully processed all files!")
        print(response.json())
    else:
        print(f"❌ Processing failed: {response.status_code}")
        print(response.text)

if __name__ == "__main__":
    process_uploaded_files()
# Out:
# 📂 Processing files for Project ID: 12 with overlap 0 bytes...
# ✅ Successfully processed all files!
# {'signal': 'processing_success', 'inserted_chunks': 1188, 'processed_files': 1188}

# %%
# Pushing the Documents into Vector Database

import requests

PROJECT_ID = 12
ENDPOINT_URL = f"http://127.0.0.1:5000/api/v1/nlp/index/push/{PROJECT_ID}"

def push_index():
    """Triggers the push index operation for the specified project."""
    # Send a dummy or empty JSON payload if body is required
    response = requests.post(ENDPOINT_URL, json={})

    if response.status_code == 200:
        print("✅ Successfully pushed the index!")
        print(response.json())
    else:
        print(f"❌ Failed to push the index: {response.status_code}")
        print(response.text)


push_index()
# Out:
# ✅ Successfully pushed the index!
# {'signal': 'insert_into_vectordb_success', 'inserted_items_count': 1188}
